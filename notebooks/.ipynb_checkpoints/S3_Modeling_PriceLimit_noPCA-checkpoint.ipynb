# %% [markdown]
# # S2: AirBnb NYC 2024 Listings
# by: Tam Trinh
# March 24, 2025

# %% [markdown]
# <a id="0"></a> <br>
# ## Table of Contents
#
# - [Sprint Goals](#6)
# - [Introduction](#1)
# - [Set-up and Dataset Overview](#7)
# - [Part 1: EDA](#2)
# - [Part 2: Preprocessing](#3)
# - [Part 3: Modeling](#4)
# - [Stylized Visualizations](#8)
# - [Conclusion](#5)

# %% [markdown]
# <a id="7"></a>
# ## Set-up and Dataset Overview

# %%
# imports for functionality and plotting
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# optional imports
import warnings
import pickle

# imports for preprocessing
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# imports for modeling
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from tempfile import mkdtemp
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor

from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.inspection import permutation_importance

# %%
# ignore warnings
from warnings import filterwarnings
warnings.filterwarnings('ignore')

# %%
# load cleaned dataset
cleaned_airbnb = pd.read_csv("../data/cleaned_airbnb.csv")

# %%
cleaned_limit500 = cleaned_airbnb[cleaned_airbnb["price"] <= 500]

# %%
cleaned_limit1000 = cleaned_airbnb[cleaned_airbnb["price"] <= 1000]

# %% [markdown]
# __________________

# %% [markdown]
# <a id="4"></a>
# ## Part 3: Modeling

# %% [markdown]
# ### Train/test split

# %%
# split the data into train and test sets
X = cleaned_limit500.loc[:, cleaned_airbnb.columns != "price"]
y = cleaned_limit500["price"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
# optional:

# # sample for quicker test runs
# sample_airbnb = cleaned_airbnb.sample(n=5000, random_state=1)

# # split the data into train and test sets
# X = sample_airbnb.loc[:, sample_airbnb.columns != "price"]
# y = sample_airbnb["price"]

# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %% [markdown]
# ### Linear Regression Modeling

# %% [markdown]
# #### Fit initial linear regression model

# %%
# initialize linear regression model
linreg = LinearRegression()

# fit logistic regression model to xtrain
linreg.fit(X_train, y_train)

# get scores for train and test
print(f"Train score: {linreg.score(X_train, y_train)}")
print(f"Test score: {linreg.score(X_test, y_test)}")
# Out:
# Train score: 0.4164109391444635
# Test score: 0.3862578018771333

# %% [markdown]
# An initial testing of a linear regression model is performed to poor results. Surprisingly, the test score performed better than the train score.

# %% [markdown]
# #### Feature Coefficients

# %%
linreg_coef = pd.Series(linreg.coef_, index=X_test.columns)

# %%
linreg_coef.sort_values(ascending=False)
# Out:
# roomtype_Entire home/apt           30.330792
# roomtype_Hotel room                27.704304
# bedrooms                           25.789968
# ratings_5                          22.455410
# ratings_4.8                        20.073054
# neighgroup_Queens                  18.331859
# latitude                           16.148882
# neighgroup_Manhattan               14.843848
# license_Has License                13.724171
# license_Exempt                     13.418323
# baths                              13.384154
# beds                               12.657458
# ratings_No rating                   8.003885
# neighgroup_Bronx                    6.514783
# ratings_4.6                         3.941798
# neighgroup_Brooklyn                 3.363830
# reviews_per_month                   0.961540
# neighborhood_avgprice               0.254980
# availability_365                    0.028248
# minimum_nights                     -0.009709
# calculated_host_listings_count     -0.020297
# number_of_reviews                  -0.036622
# number_of_reviews_ltm              -0.084888
# last_review_month                  -0.520513
# month                              -0.520513
# last_review_year                   -3.241074
# ratings_4.4                        -4.733481
# ratings_less3                      -6.345995
# ratings_4.0                        -7.174335
# ratings_4.2                        -7.938333
# ratings_New                        -8.945463
# ratings_3.0                       -19.336541
# roomtype_Private room             -26.662257
# license_No License                -27.142494
# roomtype_Shared room              -31.372838
# neighgroup_Staten Island          -43.054320
# longitude                        -185.922670
# dtype: float64

# %% [markdown]
# #### Set-up pipeline and gridsearch

# %%
estimators = [("scaler", StandardScaler()),
              ("pca", PCA()),
              ('linreg', LinearRegression())]

cachedir = mkdtemp()
pipe = Pipeline(estimators, memory=cachedir)

params = {"scaler": [StandardScaler(), None], 
          "pca__n_components": [5, 10, 20,]
}

grid_search = GridSearchCV(pipe, param_grid=params, cv=5)

# %% [markdown]
# A pipeline and gridsearch structure is built to run the model through. The StandardScaler, PCA, and Linear Regression are used.

# %% [markdown]
# #### Fit the gridsearch best fit model

# %%
# linreg_best = grid_search.fit(X_train, y_train)

# %%
# linreg_best.best_estimator_
# Out:
# Pipeline(memory='/var/folders/s2/vdwvjj2j24d4tg5yz10ycr080000gn/T/tmpme90m9c8',
#          steps=[('scaler', None), ('pca', PCA(n_components=20)),
#                 ('linreg', LinearRegression())])

# %%
# print(f"The best fit scaler is: {linreg_best.best_estimator_[0]}")
# print(f"The best fit number of PCA components is: {linreg_best.best_estimator_[1]}")
# print(f"The best fit model is: {linreg_best.best_estimator_[2]}")
# Out:
# The best fit scaler is: None
# The best fit number of PCA components is: PCA(n_components=20)
# The best fit model is: LinearRegression()

# %% [markdown]
# The gridsearch parameters improved the test score from 0.12 to 0.13, being able to explain 13% of the price information. For the gridsearch the StandardScaler performed better than no scaler, and PCA 10 components performed the best. Since the lowest number of PCA performed the best, this can indicate that the features might not be helping with the price prediction. Perhaps they are not linearly correlated with price. Furthur analysis can look into non-linear relationship modeling.

# %%
# # linreg_best train and test scores
# print(f"Train score: {linreg_best.score(X_train, y_train)}")
# print(f"Test score: {linreg_best.score(X_test, y_test)}")
# Out:
# Train score: 0.4042306079175021
# Test score: 0.37443973415035925

# %%
# make array of y_pred
y_pred = linreg.predict(X_test)

# %%
# Calculate MSE
mse = mean_squared_error(y_test, y_pred)

# Calculate RMSE
rmse = np.sqrt(mse)

print("RMSE:", rmse)
# Out:
# RMSE: 71.49740301674726

# %%
# Calculate MAE
mae = mean_absolute_error(y_test, y_pred)

print("MAE:", mae)
# Out:
# MAE: 51.31882969706625

# %%
# compare y_pred to y_true

# add to df
y_truevspred = pd.DataFrame({"True_y": y_test, "Pred_y": y_pred})

# display
y_truevspred
# Out:
#        True_y      Pred_y
# 16115   357.0  196.897242
# 1289     85.0  142.190849
# 2465    190.0  198.587091
# 9515    286.0  287.332765
# 12319   180.0  151.433778
# ...       ...         ...
# 13030   150.0  190.887507
# 15081   229.0  137.900824
# 9385    100.0  118.910609
# 3356    214.0  169.474244
# 1808    106.0  166.784116
#
# [4006 rows x 2 columns]

# %% [markdown]
# #### Plots of predicted vs actual

# %%
# scatterplot

plt.figure(figsize=(6,4))
ax = sns.scatterplot(x=y_pred, y=y_test)
plt.suptitle("Scatterplot of y_pred and y_test")
plt.xlabel("y_pred")
plt.ylabel("y_test")

x_vals = np.linspace(y_pred.min(), y_pred.max(), 100)
ax.plot(x_vals, x_vals, color='red', linestyle='--', linewidth=2) 

plt.show()

# %% [markdown]
# In this scatterplot of the predicted price values versus the actual price values, the predicted was capped at about 3,000, meanwhile the actual value went as high as 10,000. In linear regression, this punishes the model severely as the large values of error are squared, giving more weight to outliers. In the case of this dataset, the outliers are already large, and this magnifies the effect of the outliers, further punishing the model. Further analysis could look into handling the outliers.

# %%
# scatterplot

plt.figure(figsize=(6,4))
ax = sns.scatterplot(x=y_pred, y=y_test)
plt.suptitle("Scatterplot of y_pred and y_test")
plt.xlabel("y_pred")
plt.ylabel("y_test")

x_vals = np.linspace(y_pred.min(), y_pred.max(), 100)
ax.plot(x_vals, x_vals, color='red', linestyle='--', linewidth=2) 

plt.xlim(0, 1000)
plt.ylim(0, 1000)

plt.show()

# %% [markdown]
# When zooming into the values less than 1,000, the model seemed to performed much better. With similar amounts above the line, showing when actual price is higher than predicted price, and a similar amount under the line, showing when predicted price is higher than actual price.

# %% [markdown]
# #### Pickle and save model

# %%
pickle.dump(linreg_best, open("../models/linreg_model.pkl","wb"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 pickle.dump(linreg_best, open("../models/linreg_model.pkl","wb"))
#
# NameError: name 'linreg_best' is not defined

# %%
# # to load model (optional)
# linreg_model = pickle.load(open("../models/linreg_model.pkl","rb"))

# %% [markdown]
# ***

# %% [markdown]
# ### XGBoost Modeling

# %%
# initialize xgboost model
xgb_model = XGBRegressor()

# fit logistic regression model to xtrain
xgb_model.fit(X_train, y_train)

# get scores for train and test
print(f"Train score: {xgb_model.score(X_train, y_train)}")
print(f"Test score: {xgb_model.score(X_test, y_test)}")
# Out:
# Train score: 0.7979406803824365
# Test score: 0.5248005633205888

# %% [markdown]
# An initial testing of a linear regression model is performed to poor results. Surprisingly, the test score performed better than the train score.

# %% [markdown]
# #### Feature Importance

# %%
importances = xgb_model.feature_importances_

feature_importances = pd.Series(importances, index=X_test.columns)

sorted_importances = feature_importances.sort_values(ascending=False)
sorted_importances
# Out:
# roomtype_Entire home/apt          0.293657
# license_No License                0.248750
# baths                             0.095256
# bedrooms                          0.041803
# roomtype_Hotel room               0.025196
# license_Exempt                    0.022942
# beds                              0.022604
# neighborhood_avgprice             0.019371
# calculated_host_listings_count    0.017419
# ratings_No rating                 0.016141
# ratings_4.8                       0.014345
# neighgroup_Manhattan              0.013910
# minimum_nights                    0.013362
# ratings_5                         0.012782
# longitude                         0.010837
# reviews_per_month                 0.009672
# availability_365                  0.009060
# ratings_3.0                       0.008836
# number_of_reviews_ltm             0.007052
# latitude                          0.006933
# ratings_4.2                       0.006909
# neighgroup_Queens                 0.006892
# neighgroup_Brooklyn               0.006827
# month                             0.006735
# last_review_year                  0.006628
# roomtype_Shared room              0.006622
# ratings_4.0                       0.006504
# ratings_4.6                       0.006493
# roomtype_Private room             0.006448
# ratings_less3                     0.006426
# number_of_reviews                 0.005840
# ratings_New                       0.005237
# license_Has License               0.005148
# ratings_4.4                       0.004205
# neighgroup_Bronx                  0.003156
# neighgroup_Staten Island          0.000000
# last_review_month                 0.000000
# dtype: float32

# %%
# alternative booster importance
booster = xgb_model.get_booster()
importance_dict = booster.get_score(importance_type='cover')  

# display
importance_df = pd.DataFrame.from_dict(importance_dict, orient='index', columns=['Importance'])
importance_df = importance_df.sort_values(by='Importance', ascending=False)
importance_df
# Out:
#                                   Importance
# ratings_3.0                     15870.599609
# license_No License               6737.636230
# roomtype_Shared room             6666.000000
# ratings_less3                    6263.500000
# ratings_New                      5838.399902
# license_Has License              4449.643066
# last_review_year                 3768.469971
# ratings_4.8                      3704.600098
# ratings_4.0                      2962.866699
# ratings_4.2                      2381.933350
# roomtype_Entire home/apt         2172.188477
# number_of_reviews_ltm            2160.847412
# calculated_host_listings_count   2114.356934
# minimum_nights                   2071.958740
# ratings_5                        2050.399902
# longitude                        2009.608887
# number_of_reviews                1976.989014
# availability_365                 1957.030151
# reviews_per_month                1833.272461
# baths                            1832.636353
# latitude                         1764.436890
# neighborhood_avgprice            1719.569336
# beds                             1716.331299
# bedrooms                         1594.840698
# month                            1505.770142
# roomtype_Hotel room              1436.599976
# roomtype_Private room            1397.681763
# neighgroup_Manhattan             1385.300049
# neighgroup_Brooklyn              1354.727295
# ratings_4.4                      1335.500000
# ratings_No rating                1149.000000
# license_Exempt                    963.187500
# ratings_4.6                       946.500000
# neighgroup_Queens                 483.750000
# neighgroup_Bronx                  133.333328

# %%
# Airbnb color palette
airbnb_teal = "#007A87"
background_gray = "#F7F7F7"
text_gray = "#484848"

# Select top 10 features
top_features = sorted_importances.head(10)

plt.figure(figsize=(8, 5))
sns.set_style("whitegrid")

sns.barplot(x=top_features.values, y=top_features.index, color=airbnb_teal)

# Styling
plt.title("Top 10 Feature Importances (XGBoost)", fontsize=14, fontweight='bold', color=text_gray)
plt.xlabel("Importance", fontsize=12, color=text_gray)
plt.ylabel("Feature", fontsize=12, color=text_gray)
plt.xticks(color=text_gray)
plt.yticks(color=text_gray)
plt.gca().set_facecolor(background_gray)
plt.gcf().set_facecolor('white')
sns.despine()

# Save if needed
plt.savefig("../plots/feature_imp.png", dpi=300)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Set-up pipeline and gridsearch

# %%
estimators = [("scaler", StandardScaler()),
              ("pca", PCA()),
              ('xgb', XGBRegressor())]

cachedir = mkdtemp()
pipe = Pipeline(estimators, memory=cachedir)

params = {"scaler": [StandardScaler(), None], 
          "pca__n_components": [5, 10, 20,]
}

grid_search = GridSearchCV(pipe, param_grid=params, cv=5)

# %% [markdown]
# A pipeline and gridsearch structure is built to run the model through. The StandardScaler, PCA, and Linear Regression are used.

# %% [markdown]
# #### Fit the gridsearch best fit model

# %%
# xgb_best = grid_search.fit(X_train, y_train)

# %%
# xgb_best.best_estimator_

# %%
# print(f"The best fit scaler is: {xgb_best.best_estimator_[0]}")
# print(f"The best fit number of PCA components is: {xgb_best.best_estimator_[1]}")
# print(f"The best fit model is: {xgb_best.best_estimator_[2]}")

# %% [markdown]
# The gridsearch parameters improved the test score from 0.12 to 0.13, being able to explain 13% of the price information. For the gridsearch the StandardScaler performed better than no scaler, and PCA 10 components performed the best. Since the lowest number of PCA performed the best, this can indicate that the features might not be helping with the price prediction. Perhaps they are not linearly correlated with price. Furthur analysis can look into non-linear relationship modeling.

# %%
# # linreg_best train and test scores
# print(f"Train score: {xgb_best.score(X_train, y_train)}")
# print(f"Test score: {xgb_best.score(X_test, y_test)}")

# %%
# make array of y_pred
y_pred = xgb_model.predict(X_test)

# %%
# Calculate MSE
mse = mean_squared_error(y_test, y_pred)

# Calculate RMSE
rmse = np.sqrt(mse)

print("RMSE:", rmse)
# Out:
# RMSE: 62.91225232606841

# %%
# Calculate MAE
mae = mean_absolute_error(y_test, y_pred)

print("MAE:", mae)
# Out:
# MAE: 43.58188869443704

# %%
# compare y_pred to y_true

# add to df
y_truevspred = pd.DataFrame({"True_y": y_test, "Pred_y": y_pred})

# display
y_truevspred["Difference"] = y_truevspred["Pred_y"] - y_truevspred["True_y"]
y_truevspred
# Out:
#        True_y      Pred_y  Difference
# 16115   357.0  215.126694 -141.873306
# 1289     85.0  126.270203   41.270203
# 2465    190.0  227.377457   37.377457
# 9515    286.0  333.787903   47.787903
# 12319   180.0  209.055313   29.055313
# ...       ...         ...         ...
# 13030   150.0  150.622101    0.622101
# 15081   229.0  202.374420  -26.625580
# 9385    100.0  144.402328   44.402328
# 3356    214.0  159.505066  -54.494934
# 1808    106.0   98.273834   -7.726166
#
# [4006 rows x 3 columns]

# %% [markdown]
# #### Plots of predicted vs actual

# %%
# scatterplot

plt.figure(figsize=(6,4))
ax = sns.scatterplot(x=y_pred, y=y_test)
plt.suptitle("Scatterplot of y_pred and y_test")
plt.xlabel("y_pred")
plt.ylabel("y_test")

x_vals = np.linspace(y_pred.min(), y_pred.max(), 100)
ax.plot(x_vals, x_vals, color='red', linestyle='--', linewidth=2) 

plt.show()

# %% [markdown]
# In this scatterplot of the predicted price values versus the actual price values, the predicted was capped at about 3,000, meanwhile the actual value went as high as 10,000. In linear regression, this punishes the model severely as the large values of error are squared, giving more weight to outliers. In the case of this dataset, the outliers are already large, and this magnifies the effect of the outliers, further punishing the model. Further analysis could look into handling the outliers.

# %%
# scatterplot

plt.figure(figsize=(6,4))
ax = sns.scatterplot(x=y_pred, y=y_test)
plt.suptitle("Scatterplot of y_pred and y_test")
plt.xlabel("y_pred")
plt.ylabel("y_test")

x_vals = np.linspace(y_pred.min(), y_pred.max(), 100)
ax.plot(x_vals, x_vals, color='red', linestyle='--', linewidth=2) 

plt.xlim(0, 1000)
plt.ylim(0, 1000)

plt.show()

# %% [markdown]
# When zooming into the values less than 1,000, the model seemed to performed much better. With similar amounts above the line, showing when actual price is higher than predicted price, and a similar amount under the line, showing when predicted price is higher than actual price.

# %%
# Airbnb styling colors
airbnb_teal = "#007A87"
background_gray = "#F7F7F7"
text_gray = "#484848"
airbnb_red = "#FF5A5F"

# Generate line values for diagonal reference
x_vals = np.linspace(min(y_pred.min(), y_test.min()), max(y_pred.max(), y_test.max()), 100)

# Plot setup
plt.figure(figsize=(6, 4))
sns.set_style("whitegrid")

ax = sns.scatterplot(x=y_pred, y=y_test, color=airbnb_teal, edgecolor='white', alpha=0.7, s=50)
plt.plot(x_vals, x_vals, color=airbnb_red, linestyle='--', linewidth=2, label="Ideal Fit")

# Labels & title
plt.title("Scatterplot of Predicted vs Actual", fontsize=14, fontweight='bold', color=text_gray)
plt.xlabel("Predicted Values", fontsize=12, color=text_gray)
plt.ylabel("Actual Values", fontsize=12, color=text_gray)
plt.xticks(color=text_gray)
plt.yticks(color=text_gray)
plt.legend()

# Airbnb-styled background
plt.gca().set_facecolor(background_gray)
plt.gcf().set_facecolor('white')
sns.despine()

# Save if needed
# plt.savefig("airbnb_scatterplot.png", dpi=300)

plt.tight_layout()
plt.show()

# %%
# Airbnb-inspired color palette
airbnb_red = '#FF5A5F'
background_gray = '#F7F7F7'
text_gray = '#484848'

# Example best-fit line (replace with actual regression if available)
line = np.polyfit(y_pred, y_test, 1)
line_fn = np.poly1d(line)

# Set style
plt.style.use('default')
sns.set_style("whitegrid")
plt.rcParams.update({
    'axes.facecolor': background_gray,
    'axes.edgecolor': 'white',
    'axes.titleweight': 'bold',
    'axes.titlesize': 16,
    'axes.labelsize': 12,
    'font.family': 'Arial',  # or 'Nunito', 'Arial', etc.
    'xtick.color': text_gray,
    'ytick.color': text_gray,
    'axes.labelcolor': text_gray,
    'figure.facecolor': 'white'
})

# Plot
plt.figure(figsize=(6, 5))
plt.scatter(y_pred, y_test, color='#007A87', alpha=0.1, edgecolors='white', linewidth=0.5)
plt.plot(y_pred, line_fn(y_pred), color=airbnb_red, linewidth=2, linestyle='--')

plt.title('XGBoost Model Predicted Price vs Actual Price', color=text_gray)
plt.xlabel('Predicted Rental Price')
plt.ylabel('Actual Rental Price')

# Zoom in: set axis limits
plt.xlim(0, 500)
plt.ylim(0, 500)

# Clean up ticks
plt.tick_params(axis='both', which='major', labelsize=10)
sns.despine()
plt.tight_layout()

# Save plot
plt.savefig("../plots/xgboost_scatterplot_predvstest.png", dpi=300)

plt.show()

# %%
# Airbnb-inspired color palette
airbnb_red = '#FF5A5F'
background_gray = '#F7F7F7'
text_gray = '#484848'

# Example best-fit line (replace with actual regression if available)
line = np.polyfit(y_pred, y_test, 1)
line_fn = np.poly1d(line)

# Set style
plt.style.use('default')
sns.set_style("whitegrid")
plt.rcParams.update({
    'axes.facecolor': background_gray,
    'axes.edgecolor': 'white',
    'axes.titleweight': 'bold',
    'axes.titlesize': 16,
    'axes.labelsize': 12,
    'font.family': 'Arial',  # or 'Nunito', 'Arial', etc.
    'xtick.color': text_gray,
    'ytick.color': text_gray,
    'axes.labelcolor': text_gray,
    'figure.facecolor': 'white'
})

# Plot
plt.figure(figsize=(6, 5))
plt.scatter(y_test, y_pred, color='#007A87', alpha=0.1, edgecolors='white', linewidth=0.5)
plt.plot(y_pred, line_fn(y_pred), color=airbnb_red, linewidth=2, linestyle='--')

plt.title('XGBoost Model Predicted Price vs Actual Price', color=text_gray)
plt.ylabel('Predicted Rental Price')
plt.xlabel('Actual Rental Price')

# Zoom in: set axis limits
plt.xlim(0, 500)
plt.ylim(0, 500)

# Clean up ticks
plt.tick_params(axis='both', which='major', labelsize=10)
sns.despine()
plt.tight_layout()

# Save plot
plt.savefig("../plots/xgboost_scatterplot_predvstest.png", dpi=300)

plt.show()

# %% [markdown]
# #### Pickle and save model

# %%
pickle.dump(xgb_best, open("../models/xgb_model.pkl","wb"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 pickle.dump(xgb_best, open("../models/xgb_model.pkl","wb"))
#
# NameError: name 'xgb_best' is not defined

# %% [markdown]
# _________________________________

# %% [markdown]
# ### Random Forest Modeling

# %%
# initialize rforest
rforest_model = RandomForestRegressor()

# fit logistic regression model to xtrain
rforest_model.fit(X_train, y_train)

# get scores for train and test
print(f"Train score: {rforest_model.score(X_train, y_train)}")
print(f"Test score: {rforest_model.score(X_test, y_test)}")
# Out:
# Train score: 0.9362476904586098
# Test score: 0.5142537654382882

# %% [markdown]
# An initial testing of a linear regression model is performed to poor results. Surprisingly, the test score performed better than the train score.

# %% [markdown]
# #### Feature Importance

# %%
importances = rforest_model.feature_importances_

feature_importances = pd.Series(importances, index=X_test.columns)

feature_importances.sort_values(ascending=False)
# Out:
# roomtype_Entire home/apt          0.187040
# longitude                         0.091527
# baths                             0.083362
# latitude                          0.080290
# neighborhood_avgprice             0.073836
# reviews_per_month                 0.065856
# bedrooms                          0.059921
# availability_365                  0.056599
# calculated_host_listings_count    0.053723
# number_of_reviews                 0.042006
# beds                              0.033948
# number_of_reviews_ltm             0.028926
# license_No License                0.028203
# minimum_nights                    0.016632
# last_review_month                 0.016544
# month                             0.016308
# last_review_year                  0.010769
# ratings_5                         0.008249
# ratings_4.8                       0.006759
# roomtype_Private room             0.006359
# ratings_4.6                       0.005277
# license_Exempt                    0.004184
# ratings_4.4                       0.003918
# ratings_4.2                       0.002929
# neighgroup_Manhattan              0.002890
# ratings_No rating                 0.002459
# neighgroup_Brooklyn               0.002032
# ratings_4.0                       0.001998
# neighgroup_Queens                 0.001725
# license_Has License               0.001544
# roomtype_Shared room              0.000899
# ratings_3.0                       0.000867
# roomtype_Hotel room               0.000799
# ratings_New                       0.000774
# neighgroup_Bronx                  0.000558
# neighgroup_Staten Island          0.000160
# ratings_less3                     0.000131
# dtype: float64

# %%
# Compute permutation importance
result = permutation_importance(rforest_model, X_test, y_test, n_repeats=10, random_state=0)

# Convert to Series for plotting
perm_importances = pd.Series(result.importances_mean, index=X.columns)
perm_importances
# Out:
# latitude                          4.591567e-02
# longitude                         9.857851e-02
# minimum_nights                    1.531150e-02
# number_of_reviews                 9.829046e-03
# reviews_per_month                 3.702824e-02
# calculated_host_listings_count    9.351222e-02
# availability_365                  3.336417e-02
# number_of_reviews_ltm             1.216452e-02
# bedrooms                          1.014375e-01
# beds                              5.307590e-02
# baths                             7.535770e-02
# month                            -2.890860e-04
# neighborhood_avgprice             8.779919e-02
# last_review_month                 7.500660e-05
# last_review_year                  2.409173e-03
# neighgroup_Bronx                  5.943672e-05
# neighgroup_Brooklyn               2.407474e-04
# neighgroup_Manhattan              2.958512e-03
# neighgroup_Queens                 5.550569e-05
# neighgroup_Staten Island          9.827418e-05
# roomtype_Entire home/apt          2.738428e-01
# roomtype_Hotel room               4.837617e-04
# roomtype_Private room             5.528674e-04
# roomtype_Shared room              2.629319e-04
# license_Exempt                    3.036977e-03
# license_Has License               7.309725e-04
# license_No License                7.380975e-02
# ratings_3.0                      -1.684016e-04
# ratings_4.0                      -2.097217e-04
# ratings_4.2                      -1.709059e-04
# ratings_4.4                      -4.611822e-04
# ratings_4.6                       1.426212e-04
# ratings_4.8                       3.144568e-03
# ratings_5                         5.907152e-03
# ratings_New                      -1.779195e-04
# ratings_No rating                -1.117229e-04
# ratings_less3                    -4.470369e-07
# dtype: float64

# %% [markdown]
# #### Set-up pipeline and gridsearch

# %%
estimators = [("scaler", StandardScaler()),
              ("pca", PCA()),
              ('rf', RandomForestRegressor())]

cachedir = mkdtemp()
pipe = Pipeline(estimators, memory=cachedir)

params = {"scaler": [StandardScaler(), None], 
          "pca__n_components": [5, 10, 20,]
}

grid_search = GridSearchCV(pipe, param_grid=params, cv=5)

# %% [markdown]
# A pipeline and gridsearch structure is built to run the model through. The StandardScaler, PCA, and Linear Regression are used.

# %% [markdown]
# #### Fit the gridsearch best fit model

# %%
# rforest_best = grid_search.fit(X_train, y_train)

# %%
# rforest_best.best_estimator_

# %%
# print(f"The best fit scaler is: {rforest_best.best_estimator_[0]}")
# print(f"The best fit number of PCA components is: {rforest_best.best_estimator_[1]}")
# print(f"The best fit model is: {rforest_best.best_estimator_[2]}")

# %% [markdown]
# The gridsearch parameters improved the test score from 0.12 to 0.13, being able to explain 13% of the price information. For the gridsearch the StandardScaler performed better than no scaler, and PCA 10 components performed the best. Since the lowest number of PCA performed the best, this can indicate that the features might not be helping with the price prediction. Perhaps they are not linearly correlated with price. Furthur analysis can look into non-linear relationship modeling.

# %%
# linreg_best train and test scores
print(f"Train score: {rforest_model.score(X_train, y_train)}")
print(f"Test score: {rforest_model.score(X_test, y_test)}")
# Out:
# Train score: 0.9362476904586098
# Test score: 0.5142537654382882

# %%
# make array of y_pred
y_pred = rforest_model.predict(X_test)

# %%
# Calculate MSE
mse = mean_squared_error(y_test, y_pred)

# Calculate RMSE
rmse = np.sqrt(mse)

print("RMSE:", rmse)
# Out:
# RMSE: 63.60657288169492

# %%
# Calculate MAE
mae = mean_absolute_error(y_test, y_pred)

print("MAE:", mae)
# Out:
# MAE: 43.71843984023964

# %%
# compare y_pred to y_true

# add to df
y_truevspred = pd.DataFrame({"True_y": y_test, "Pred_y": y_pred})

# display
y_truevspred
# Out:
#        True_y  Pred_y
# 16115   357.0  214.27
# 1289     85.0  162.64
# 2465    190.0  198.99
# 9515    286.0  335.60
# 12319   180.0  161.51
# ...       ...     ...
# 13030   150.0  146.58
# 15081   229.0  216.53
# 9385    100.0  157.57
# 3356    214.0  164.49
# 1808    106.0  115.33
#
# [4006 rows x 2 columns]

# %% [markdown]
# #### Plots of predicted vs actual

# %%
# scatterplot

plt.figure(figsize=(6,4))
ax = sns.scatterplot(x=y_pred, y=y_test)
plt.suptitle("Scatterplot of y_pred and y_test")
plt.xlabel("y_pred")
plt.ylabel("y_test")

x_vals = np.linspace(y_pred.min(), y_pred.max(), 100)
ax.plot(x_vals, x_vals, color='red', linestyle='--', linewidth=2) 

plt.show()

# %% [markdown]
# In this scatterplot of the predicted price values versus the actual price values, the predicted was capped at about 3,000, meanwhile the actual value went as high as 10,000. In linear regression, this punishes the model severely as the large values of error are squared, giving more weight to outliers. In the case of this dataset, the outliers are already large, and this magnifies the effect of the outliers, further punishing the model. Further analysis could look into handling the outliers.

# %%
# scatterplot

plt.figure(figsize=(6,4))
ax = sns.scatterplot(x=y_pred, y=y_test)
plt.suptitle("Scatterplot of y_pred and y_test")
plt.xlabel("y_pred")
plt.ylabel("y_test")

x_vals = np.linspace(y_pred.min(), y_pred.max(), 100)
ax.plot(x_vals, x_vals, color='red', linestyle='--', linewidth=2) 

plt.xlim(0, 1000)
plt.ylim(0, 1000)

plt.show()

# %% [markdown]
# When zooming into the values less than 1,000, the model seemed to performed much better. With similar amounts above the line, showing when actual price is higher than predicted price, and a similar amount under the line, showing when predicted price is higher than actual price.

# %% [markdown]
# #### Pickle and save model

# %%
pickle.dump(rforest_best, open("../models/rf_model.pkl","wb"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 pickle.dump(rforest_best, open("../models/rf_model.pkl","wb"))
#
# NameError: name 'rforest_best' is not defined
